# %% [markdown]
# <table>
# <colgroup>
# <col style="width: 50%" />
# <col style="width: 50%" />
# </colgroup>
# <thead>
# <tr class="header">
# <th><p>8/7/23, 11:15 AM</p>
# <p>In [1]:</p>
# <p>In [2]:</p>
# <p>In [3]:</p></th>
# <th><p>task1_a-Copy1</p>
# <table>
# <colgroup>
# <col style="width: 100%" />
# </colgroup>
# <thead>
# <tr class="header">
# <th><blockquote>
# <p><strong>import</strong> pandas <strong>as</strong> pd<br />
# <strong>import</strong> matplotlib.pyplot <strong>as</strong> plt<br />
# <strong>import</strong> seaborn <strong>as</strong> sns<br />
# <strong>from</strong> sklearn.model_selection <strong>import</strong>
# train_test_split <strong>from</strong> sklearn.linear_model
# <strong>import</strong> LinearRegression<br />
# <strong>from</strong> sklearn.metrics <strong>import</strong>
# mean_squared_error, r2_score</p>
# </blockquote></th>
# </tr>
# </thead>
# <tbody>
# </tbody>
# </table>
# <table>
# <colgroup>
# <col style="width: 100%" />
# </colgroup>
# <thead>
# <tr class="header">
# <th><blockquote>
# <p>df <strong>=</strong> pd<strong>.</strong>read_csv('data.csv')</p>
# </blockquote></th>
# </tr>
# </thead>
# <tbody>
# </tbody>
# </table>
# <table>
# <colgroup>
# <col style="width: 100%" />
# </colgroup>
# <thead>
# <tr class="header">
# <th><blockquote>
# <p>print(df<strong>.</strong>head())</p>
# </blockquote></th>
# </tr>
# </thead>
# <tbody>
# </tbody>
# </table></th>
# </tr>
# </thead>
# <tbody>
# </tbody>
# </table>
#
# > date price bedrooms bathrooms sqft_living sqft_lot \\ 0 2014-05-02
# > 00:00:00 313000.0 3.0 1.50 1340 7912 1 2014-05-02 00:00:00 2384000.0
# > 5.0 2.50 3650 9050 2 2014-05-02 00:00:00 342000.0 3.0 2.00 1930 11947
# > 3 2014-05-02 00:00:00 420000.0 3.0 2.25 2000 8030 4 2014-05-02
# > 00:00:00 550000.0 4.0 2.50 1940 10500
# >
# > floors waterfront view condition sqft_above sqft_basement yr_built \\
# > 0 1.5 0 0 3 1340 0 1955 1 2.0 0 4 5 3370 280 1921 2 1.0 0 0 4 1930 0
# > 1966 3 1.0 0 0 4 1000 1000 1963 4 1.0 0 0 4 1140 800 1976
# >
# > yr_renovated street city statezip country 0 2005 18810 Densmore Ave N
# > Shoreline WA 98133 USA 1 0 709 W Blaine St Seattle WA 98119 USA 2 0
# > 26206-26214 143rd Ave SE Kent WA 98042 USA 3 0 857 170th Pl NE
# > Bellevue WA 98008 USA 4 1992 9105 170th Ave NE Redmond WA 98052 USA
#
# <table>
# <colgroup>
# <col style="width: 33%" />
# <col style="width: 33%" />
# <col style="width: 33%" />
# </colgroup>
# <thead>
# <tr class="header">
# <th>In [4]:</th>
# <th><table>
# <colgroup>
# <col style="width: 100%" />
# </colgroup>
# <thead>
# <tr class="header">
# <th><blockquote>
# <p>print(df<strong>.</strong>describe())</p>
# </blockquote></th>
# </tr>
# </thead>
# <tbody>
# </tbody>
# </table></th>
# <th rowspan="2">1/5</th>
# </tr>
# <tr class="odd">
# <th colspan="2">file:///C:/Users/IFRAN/Downloads/task1_a-Copy1.html</th>
# </tr>
# </thead>
# <tbody>
# </tbody>
# </table>
#
# 8/7/23, 11:15 AM task1_a-Copy1
#
# > price bedrooms bathrooms sqft_living sqft_lot \\ count 4.600000e+03
# > 4600.000000 4600.000000 4600.000000 4.600000e+03 mean 5.519630e+05
# > 3.400870 2.160815 2139.346957 1.485252e+04 std 5.638347e+05 0.908848
# > 0.783781 963.206916 3.588444e+04 min 0.000000e+00 0.000000 0.000000
# > 370.000000 6.380000e+02 25% 3.228750e+05 3.000000 1.750000 1460.000000
# > 5.000750e+03 50% 4.609435e+05 3.000000 2.250000 1980.000000
# > 7.683000e+03 75% 6.549625e+05 4.000000 2.500000 2620.000000
# > 1.100125e+04 max 2.659000e+07 9.000000 8.000000 13540.000000
# > 1.074218e+06
# >
# > floors waterfront view condition sqft_above \\ count 4600.000000
# > 4600.000000 4600.000000 4600.000000 4600.000000 mean 1.512065 0.007174
# > 0.240652 3.451739 1827.265435 std 0.538288 0.084404 0.778405 0.677230
# > 862.168977 min 1.000000 0.000000 0.000000 1.000000 370.000000 25%
# > 1.000000 0.000000 0.000000 3.000000 1190.000000 50% 1.500000 0.000000
# > 0.000000 3.000000 1590.000000 75% 2.000000 0.000000 0.000000 4.000000
# > 2300.000000 max 3.500000 1.000000 4.000000 5.000000 9410.000000
# >
# > sqft_basement yr_built yr_renovated
# > count 4600.000000 4600.000000 4600.000000
# > mean 312.081522 1970.786304 808.608261
# > std 464.137228 29.731848 979.414536
# > min 0.000000 1900.000000 0.000000
# > 25% 0.000000 1951.000000 0.000000
# > 50% 0.000000 1976.000000 0.000000
# > 75% 610.000000 1997.000000 1999.000000
# > max 4820.000000 2014.000000 2014.000000
#
# <table>
# <colgroup>
# <col style="width: 50%" />
# <col style="width: 50%" />
# </colgroup>
# <thead>
# <tr class="header">
# <th>In [5]:</th>
# <th><table>
# <colgroup>
# <col style="width: 100%" />
# </colgroup>
# <thead>
# <tr class="header">
# <th><blockquote>
# <p>print(df<strong>.</strong>isnull()<strong>.</strong>sum())</p>
# </blockquote></th>
# </tr>
# </thead>
# <tbody>
# </tbody>
# </table></th>
# </tr>
# </thead>
# <tbody>
# </tbody>
# </table>
#
# > date 0
# > price 0
# > bedrooms 0
# > bathrooms 0
# > sqft_living 0
# > sqft_lot 0
# > floors 0
# > waterfront 0
# > view 0
# > condition 0
# > sqft_above 0
# > sqft_basement 0
# > yr_built 0
# > yr_renovated 0
# > street 0
# > city 0
# > statezip 0
# > country 0
# > dtype: int64
#
# <table>
# <colgroup>
# <col style="width: 50%" />
# <col style="width: 50%" />
# </colgroup>
# <thead>
# <tr class="header">
# <th>In [6]:</th>
# <th><table>
# <colgroup>
# <col style="width: 100%" />
# </colgroup>
# <thead>
# <tr class="header">
# <th><blockquote>
# <p>correlation_matrix <strong>=</strong>
# df<strong>.</strong>corr()<br />
# sns<strong>.</strong>heatmap(correlation_matrix,
# annot<strong>=True</strong>, cmap<strong>=</strong>'coolwarm')
# plt<strong>.</strong>title("Correlation Matrix")<br />
# plt<strong>.</strong>show()</p>
# </blockquote></th>
# </tr>
# </thead>
# <tbody>
# </tbody>
# </table></th>
# </tr>
# </thead>
# <tbody>
# </tbody>
# </table>
#
# | C:\Users\IFRAN\AppData\Local\Temp\ipykernel_3108\3746533019.py:1: FutureWarning: T |
# |------------------------------------------------------------------------|
#
# <table>
# <colgroup>
# <col style="width: 100%" />
# </colgroup>
# <thead>
# <tr class="header">
# <th><blockquote>
# <p>he default value of numeric_only in DataFrame.corr is deprecated. In
# a future vers</p>
# </blockquote></th>
# </tr>
# </thead>
# <tbody>
# </tbody>
# </table>
#
# <table>
# <colgroup>
# <col style="width: 100%" />
# </colgroup>
# <thead>
# <tr class="header">
# <th><blockquote>
# <p>ion, it will default to False. Select only valid columns or specify
# the value of n</p>
# </blockquote></th>
# </tr>
# </thead>
# <tbody>
# </tbody>
# </table>
#
# <table>
# <colgroup>
# <col style="width: 100%" />
# </colgroup>
# <thead>
# <tr class="header">
# <th><blockquote>
# <p>umeric_only to silence this warning.</p>
# </blockquote></th>
# </tr>
# </thead>
# <tbody>
# </tbody>
# </table>
#
# <table>
# <colgroup>
# <col style="width: 50%" />
# <col style="width: 50%" />
# </colgroup>
# <thead>
# <tr class="header">
# <th><blockquote>
# <p>correlation_matrix = df.corr()</p>
# </blockquote>
# <p>file:///C:/Users/IFRAN/Downloads/task1_a-Copy1.html</p></th>
# <th>2/5</th>
# </tr>
# </thead>
# <tbody>
# </tbody>
# </table>
#
# <img
# src="attachment:vertopal_9ceac0ea66ee4d7085c3b40320b35171/media/image2.png"
# style="width:1.52778in;height:0.61111in" />
#
# 8/7/23, 11:15 AM task1_a-Copy1
#
# > <img
# > src="attachment:vertopal_9ceac0ea66ee4d7085c3b40320b35171/media/image1.png"
# > style="width:6.2in;height:5.2625in" />
#
# <table>
# <colgroup>
# <col style="width: 50%" />
# <col style="width: 50%" />
# </colgroup>
# <thead>
# <tr class="header">
# <th><p>In [7]:</p>
# <p>In [8]:</p>
# <p>In [9]:</p>
# <p>In [10]:</p>
# <p>Out[10]:</p></th>
# <th><table>
# <colgroup>
# <col style="width: 100%" />
# </colgroup>
# <thead>
# <tr class="header">
# <th><blockquote>
# <p>X <strong>=</strong>
# df[['bedrooms','bathrooms','sqft_living','sqft_lot','floors','waterfront',
# y <strong>=</strong> df['price']</p>
# </blockquote></th>
# </tr>
# </thead>
# <tbody>
# </tbody>
# </table>
# <table>
# <colgroup>
# <col style="width: 100%" />
# </colgroup>
# <thead>
# <tr class="header">
# <th><blockquote>
# <p>X_train, X_test, y_train, y_test <strong>=</strong>
# train_test_split(X, y, test_size<strong>=</strong>0.2, random_sta</p>
# </blockquote></th>
# </tr>
# </thead>
# <tbody>
# </tbody>
# </table>
# <table>
# <colgroup>
# <col style="width: 100%" />
# </colgroup>
# <thead>
# <tr class="header">
# <th><blockquote>
# <p>model <strong>=</strong> LinearRegression()</p>
# </blockquote></th>
# </tr>
# </thead>
# <tbody>
# </tbody>
# </table>
# <table>
# <colgroup>
# <col style="width: 100%" />
# </colgroup>
# <thead>
# <tr class="header">
# <th><blockquote>
# <p>model<strong>.</strong>fit(X_train, y_train)</p>
# </blockquote></th>
# </tr>
# </thead>
# <tbody>
# </tbody>
# </table>
# <blockquote>
# <p>▾ LinearRegression</p>
# </blockquote></th>
# </tr>
# </thead>
# <tbody>
# </tbody>
# </table>
#
# > LinearRegression()
#
# <table>
# <colgroup>
# <col style="width: 50%" />
# <col style="width: 50%" />
# </colgroup>
# <thead>
# <tr class="header">
# <th><p>In [11]:</p>
# <p>In [12]:</p>
# <p>In [13]:</p></th>
# <th><table>
# <colgroup>
# <col style="width: 100%" />
# </colgroup>
# <thead>
# <tr class="header">
# <th><blockquote>
# <p>y_pred <strong>=</strong> model<strong>.</strong>predict(X_test)</p>
# </blockquote></th>
# </tr>
# </thead>
# <tbody>
# </tbody>
# </table>
# <table>
# <colgroup>
# <col style="width: 100%" />
# </colgroup>
# <thead>
# <tr class="header">
# <th><blockquote>
# <p>mse <strong>=</strong> mean_squared_error(y_test, y_pred)<br />
# r2 <strong>=</strong> r2_score(y_test, y_pred)</p>
# </blockquote></th>
# </tr>
# </thead>
# <tbody>
# </tbody>
# </table>
# <table>
# <colgroup>
# <col style="width: 100%" />
# </colgroup>
# <thead>
# <tr class="header">
# <th><blockquote>
# <p>print("Mean Squared Error:", mse)<br />
# print("R-squared:", r2)</p>
# </blockquote></th>
# </tr>
# </thead>
# <tbody>
# </tbody>
# </table></th>
# </tr>
# </thead>
# <tbody>
# </tbody>
# </table>
#
# > Mean Squared Error: 986869414953.9784
# >
# > R-squared: 0.03233518995632667
#
# <table>
# <colgroup>
# <col style="width: 33%" />
# <col style="width: 33%" />
# <col style="width: 33%" />
# </colgroup>
# <thead>
# <tr class="header">
# <th>In [14]:</th>
# <th><table>
# <colgroup>
# <col style="width: 100%" />
# </colgroup>
# <thead>
# <tr class="header">
# <th><blockquote>
# <p>plt<strong>.</strong>scatter(y_test, y_pred)<br />
# plt<strong>.</strong>xlabel("Actual Prices")<br />
# plt<strong>.</strong>ylabel("Predicted Prices")</p>
# </blockquote></th>
# </tr>
# </thead>
# <tbody>
# </tbody>
# </table></th>
# <th rowspan="2">3/5</th>
# </tr>
# <tr class="odd">
# <th colspan="2">file:///C:/Users/IFRAN/Downloads/task1_a-Copy1.html</th>
# </tr>
# </thead>
# <tbody>
# </tbody>
# </table>
#
# | 8/7/23, 11:15 AM | task1_a-Copy1 |
# |------------------|---------------|
#
# <table>
# <colgroup>
# <col style="width: 100%" />
# </colgroup>
# <thead>
# <tr class="header">
# <th><blockquote>
# <p>plt<strong>.</strong>title("Actual Prices vs. Predicted Prices")
# plt<strong>.</strong>show()</p>
# </blockquote></th>
# </tr>
# </thead>
# <tbody>
# </tbody>
# </table>
#
# > <img
# > src="attachment:vertopal_9ceac0ea66ee4d7085c3b40320b35171/media/image3.png"
# > style="width:5.90833in;height:4.72083in" />
#
# <table>
# <colgroup>
# <col style="width: 33%" />
# <col style="width: 33%" />
# <col style="width: 33%" />
# </colgroup>
# <thead>
# <tr class="header">
# <th>In [16]:</th>
# <th><table>
# <colgroup>
# <col style="width: 100%" />
# </colgroup>
# <thead>
# <tr class="header">
# <th><blockquote>
# <p>residuals <strong>=</strong> y_test <strong>-</strong> y_pred<br />
# plt<strong>.</strong>scatter(y_test, residuals)<br />
# plt<strong>.</strong>axhline(y<strong>=</strong>0,
# color<strong>=</strong>'red', linestyle<strong>=</strong>'--')
# plt<strong>.</strong>xlabel("Actual Prices")<br />
# plt<strong>.</strong>ylabel("Residuals")<br />
# plt<strong>.</strong>title("Residual Plot")<br />
# plt<strong>.</strong>show()</p>
# </blockquote></th>
# </tr>
# </thead>
# <tbody>
# </tbody>
# </table></th>
# <th rowspan="2">4/5</th>
# </tr>
# <tr class="odd">
# <th colspan="2">file:///C:/Users/IFRAN/Downloads/task1_a-Copy1.html</th>
# </tr>
# </thead>
# <tbody>
# </tbody>
# </table>
#
# 8/7/23, 11:15 AM task1_a-Copy1
#
# > <img
# > src="attachment:vertopal_9ceac0ea66ee4d7085c3b40320b35171/media/image4.png"
# > style="width:5.90833in;height:4.72083in" />
#
# <table>
# <colgroup>
# <col style="width: 50%" />
# <col style="width: 50%" />
# </colgroup>
# <thead>
# <tr class="header">
# <th><blockquote>
# <p>In [17]:</p>
# </blockquote></th>
# <th><table>
# <colgroup>
# <col style="width: 100%" />
# </colgroup>
# <thead>
# <tr class="header">
# <th><blockquote>
# <p>new_data <strong>=</strong>[[3,2,1500,4000,1,0,0,3]] predicted_price
# <strong>=</strong> model<strong>.</strong>predict(new_data)</p>
# </blockquote></th>
# </tr>
# </thead>
# <tbody>
# </tbody>
# </table></th>
# </tr>
# </thead>
# <tbody>
# </tbody>
# </table>
#
# | C:\Users\IFRAN\anaconda3\Lib\site-packages\sklearn\base.py:439: UserWarning: X doe |
# |------------------------------------------------------------------------|
#
# <table>
# <colgroup>
# <col style="width: 100%" />
# </colgroup>
# <thead>
# <tr class="header">
# <th><blockquote>
# <p>s not have valid feature names, but LinearRegression was fitted with
# feature names</p>
# </blockquote></th>
# </tr>
# </thead>
# <tbody>
# </tbody>
# </table>
#
# <table>
# <colgroup>
# <col style="width: 50%" />
# <col style="width: 50%" />
# </colgroup>
# <thead>
# <tr class="header">
# <th>In [18]:</th>
# <th><blockquote>
# <p>warnings.warn(</p>
# </blockquote>
# <table>
# <colgroup>
# <col style="width: 100%" />
# </colgroup>
# <thead>
# <tr class="header">
# <th><blockquote>
# <p>print("Predicted Price:", predicted_price[0])</p>
# </blockquote></th>
# </tr>
# </thead>
# <tbody>
# </tbody>
# </table></th>
# </tr>
# </thead>
# <tbody>
# </tbody>
# </table>
#
# > Predicted Price: 331038.96876929735
#
# <table>
# <colgroup>
# <col style="width: 33%" />
# <col style="width: 33%" />
# <col style="width: 33%" />
# </colgroup>
# <thead>
# <tr class="header">
# <th>In [ ]:</th>
# <th><table>
# <colgroup>
# <col style="width: 100%" />
# </colgroup>
# <tbody>
# </tbody>
# </table></th>
# <th rowspan="2">5/5</th>
# </tr>
# <tr class="odd">
# <th colspan="2">file:///C:/Users/IFRAN/Downloads/task1_a-Copy1.html</th>
# </tr>
# </thead>
# <tbody>
# </tbody>
# </table>
